# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')

# %% [markdown]
# ## 👉 download your data
#
# You can write code here to download your dataset. Or if you already have it, just leave the URL in the comments and just load it into a pandas or R (or both) dataframe.

# %%
import pandas as pd

df = pd.read_csv("mental-health-directory-2024.csv")  
df.head()
# Out:
#                         name1                                  name2  \
# 0  SpectraCare Health Systems                    Henry County Clinic
# 1  SpectraCare Health Systems             Henry County Day Treatment
# 2   South Central Alabama MHC  Covington County Mental Health Center
# 3   South Central Alabama MHC                      Montezuma Complex
# 4                RMC Anniston                                    NaN
#
#                        street1 street2       city state    zip         phone  \
# 0              219 Dothan Road     NaN  Abbeville    AL  36310  800-951-4357
# 1  1242 U.S. Highway 431 South     NaN  Abbeville    AL  36310  800-951-4357
# 2        19815 Bay Branch Road     NaN  Andalusia    AL  36420  334-222-2523
# 3            205 Academy Drive     NaN  Andalusia    AL  36420  334-428-5050
# 4         400 East 10th Street     NaN   Anniston    AL  36207  256-235-5121
#
#         intake1       intake2 intake1a intake2a  \
# 0           NaN           NaN      NaN      NaN
# 1  334-951-4357           NaN      NaN      NaN
# 2  877-530-0002           NaN      NaN      NaN
# 3  877-530-0002           NaN      NaN      NaN
# 4  256-235-5482  256-741-6484      NaN      NaN
#
#                                    service_code_info
# 0  SA MH SUMH * OP * CMHC * CHLOR FLUPH HALOP PER...
# 1  MH SUMH * OP * CMHC * CHLOR FLUPH HALOP ARIPI ...
# 2  SA MH SUMH * OP PHDT * CMHC * CHLOR FLUPH HALO...
# 3  SA MH SUMH * PHDT RES * MSMH * CHLOR FLUPH HAL...
# 4  MH * HI * IPSY * CHLOR FLUPH HALOP THIOR ARIPI...

# %% [markdown]
# ## 👉 convert addresses --> lat/long
#
# See the [census-examples](https://github.com/data4news/census-examples) repository for examples. If you need help, try asking in the class slack channel. Chances are someone in the class is struggling with the same problem as you are so we might as well all learn together in the same slack channel!

# %%
# !pip install requests-cache

# %%
# pip install "urllib3<2.0"

# %%
import pandas as pd

df = pd.read_csv("mental-health-directory-2024.csv")

df['street1'] = df['street1'].fillna("").str.strip().str.title()
df['city'] = df['city'].fillna("").str.strip().str.title()
df['state'] = df['state'].fillna("").str.strip().str.upper()
df['zip'] = df['zip'].astype(str).str.zfill(5)

nyc_boroughs = ['New York', 'Brooklyn', 'Bronx', 'Queens', 'Staten Island']
df = df[df['city'].isin(nyc_boroughs)]

df['full_address'] = df['street1'] + ', ' + df['city'] + ', NY ' + df['zip']

df.to_csv("nyc_cleaned_addresses.csv", index=False)
print("✅ Cleaned NYC addresses saved to nyc_cleaned_addresses.csv")
# Out:
# ✅ Cleaned NYC addresses saved to nyc_cleaned_addresses.csv

# %%
pip install --upgrade geopy urllib3
# Out:
# Requirement already satisfied: geopy in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: urllib3 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from time import sleep
from tqdm import tqdm  # <-- progress bar

# Load your data
df = pd.read_csv("nyc_cleaned_addresses.csv")

geolocator = Nominatim(user_agent="nyc-mental-health")

def safe_geocode(address):
    try:
        location = geolocator.geocode(address, timeout=10)
        sleep(1)  # respect Nominatim rate limit
        return location
    except Exception as e:
        print(f"Error: {address} -> {e}")
        return None

locations = []
for address in tqdm(df['full_address'], desc="Geocoding addresses"):
    loc = safe_geocode(address)
    locations.append(loc)

df['location'] = locations
df['latitude'] = df['location'].apply(lambda loc: loc.latitude if loc else None)
df['longitude'] = df['location'].apply(lambda loc: loc.longitude if loc else None)

df.to_csv("nyc_geocoded_addresses.csv", index=False)
print("✅ Done! File saved as 'nyc_geocoded_addresses.csv'")
# Out:
# Geocoding addresses: 100%|████████████████████| 125/125 [03:04<00:00,  1.48s/it]
# ✅ Done! File saved as 'nyc_geocoded_addresses.csv'

# %% [markdown]
# ## 👉 convert lat/long to census geography codes
#
# (like 'GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK', etc...)
#
# Same note as above, see [census-examples](https://github.com/data4news/census-examples) repository for examples or ask in the class slack channel if stuck.

# %%
pip install censusgeocode
# Out:
# Requirement already satisfied: censusgeocode in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (2.32.3)
# Requirement already satisfied: requests-toolbelt<1,>=0.9.0 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from censusgeocode) (0.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from requests<3,>=2.27.0->requests[security]<3,>=2.27.0->censusgeocode) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from requests<3,>=2.27.0->requests[security]<3,>=2.27.0->censusgeocode) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from requests<3,>=2.27.0->requests[security]<3,>=2.27.0->censusgeocode) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from requests<3,>=2.27.0->requests[security]<3,>=2.27.0->censusgeocode) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('nyc_geocoded_addresses.csv')
df
# Out:
#                                       name1  \
# 0                   Medstar Harbor Hospital
# 1     Astor Servs for Children and Families
# 2     Astor Servs for Children and Families
# 3     Astor Servs for Children and Families
# 4     Astor Servs for Children and Families
# ..                                      ...
# 120          South Beach Psychiatric Center
# 121          South Beach Psychiatric Center
# 122             Staten Island Mental Health
# 123  Staten Island Mental Health A Division
# 124          VA NY Harbor Healthcare System
#
#                                     name2                    street1  \
# 0                       Behavioral Health  3001 South Hanover Street
# 1             Astor Day Treatment Program    516 East Tremont Avenue
# 2                       Highbridge Clinic    1419 Shakespeare Avenue
# 3                Lawrence F Hickey Center           4010 Dyre Avenue
# 4                           Tilden Clinic          750 Tilden Street
# ..                                    ...                        ...
# 120               Ocean View Lodge Clinic         777 Seaview Avenue
# 121               South Richmond ACT Team                      - - -
# 122  A Div of Richmond University Med Ctr                      - - -
# 123  A Div of Richmond University Med Ctr       669 Castleton Avenue
# 124        Staten Island Community Clinic          1150 South Avenue
#
#                     street2           city state    zip         phone  \
# 0                 Suite 164       Brooklyn    MD  21225  410-350-7550
# 1                       NaN          Bronx    NY  10457  347-978-2450
# 2                 1st Floor          Bronx    NY  10452  718-231-3400
# 3                       NaN          Bronx    NY  10466  845-515-3000
# 4                       NaN          Bronx    NY  10467  718-231-3400
# ..                      ...            ...   ...    ...           ...
# 120  Building 10, 2nd Floor  Staten Island    NY  10305  718-667-2536
# 121                     NaN  Staten Island    NY  10305  718-668-8050
# 122                     NaN  Staten Island    NY  10301  718-818-4440
# 123                     NaN  Staten Island    NY  10301  718-818-6690
# 124               Suite 301  Staten Island    NY  10314  718-761-2973
#
#                  intake1 intake2  intake1a  intake2a  \
# 0                    NaN     NaN       NaN       NaN
# 1     929-285-3917 x1096     NaN       NaN       NaN
# 2        718-732-7080 x0     NaN       NaN       NaN
# 3           718-515-3000     NaN       NaN       NaN
# 4                    NaN     NaN       NaN       NaN
# ..                   ...     ...       ...       ...
# 120         718-667-2463     NaN       NaN       NaN
# 121                  NaN     NaN       NaN       NaN
# 122         718-818-6700     NaN       NaN       NaN
# 123  718-818-6700 x86700     NaN       NaN       NaN
# 124                  NaN     NaN       NaN       NaN
#
#                                      service_code_info  \
# 0    MH * OP PHDT * PSY * ARIPI CLOZA OLANZ OLANZF ...
# 1    MH SUMH * PHDT * PH * CHLOR HALOP PERPH ANTPYC...
# 2    SA MH SUMH * OP * OMH * NSC ANTPYCH * CBT CFT ...
# 3    MH * PHDT * PH * ANTPYCH * CBT CFT GT IPT TELE...
# 4    SA MH SUMH * OP * OMH * ANTPYCH * CBT CFT DBT ...
# ..                                                 ...
# 120  SA MH SUMH * OP * OMH * CHLOR FLUPH HALOP LOXA...
# 121  SA MH SUMH * OP * OMH * CHLOR FLUPH HALOP LOXA...
# 122  MH SUMH * OP * CMHC * CHLOR PERPH ARIPI LURAS ...
# 123  MH SUMH * OP * OMH * ARIPI QUETI RISPE NRT ANT...
# 124  SA MH SUMH * OP * VAHC * CHLOR FLUPH HALOP LOX...
#
#                                       full_address  \
# 0    3001 South Hanover Street, Brooklyn, NY 21225
# 1         516 East Tremont Avenue, Bronx, NY 10457
# 2         1419 Shakespeare Avenue, Bronx, NY 10452
# 3                4010 Dyre Avenue, Bronx, NY 10466
# 4               750 Tilden Street, Bronx, NY 10467
# ..                                             ...
# 120    777 Seaview Avenue, Staten Island, NY 10305
# 121                 - - -, Staten Island, NY 10305
# 122                 - - -, Staten Island, NY 10301
# 123  669 Castleton Avenue, Staten Island, NY 10301
# 124     1150 South Avenue, Staten Island, NY 10314
#
#                                               location   latitude  longitude
# 0                                                  NaN        NaN        NaN
# 1    516, East Tremont Avenue, East Tremont, The Br...  40.846700 -73.896822
# 2    1419, Shakespeare Avenue, High Bridge, The Bro...  40.842533 -73.921238
# 3    Public School 15, 4010, Dyre Avenue, Parkside,...  40.890946 -73.830730
# 4    750, Tilden Street, Williams Bridge, The Bronx...  40.876680 -73.862771
# ..                                                 ...        ...        ...
# 120  Staten Island Children and Youth Day Treatment...  40.582628 -74.080394
# 121  Staten Island, Richmond County, City of New Yo...  40.583456 -74.149605
# 122  Staten Island, Richmond County, City of New Yo...  40.583456 -74.149605
# 123  669, Castleton Avenue, West New Brighton, Stat...  40.635285 -74.103755
# 124  South Avenue & Lois Lane, South Avenue, Bloomf...  40.611990 -74.175993
#
# [125 rows x 17 columns]

# %%
import pandas as pd
import requests
import time
from tqdm.notebook import tqdm

df = pd.read_csv("nyc_geocoded_addresses.csv")


df['GEOID'] = None
df['STATE'] = None
df['COUNTY'] = None
df['TRACT'] = None
df['BLOCK'] = None

for idx, row in tqdm(df.iterrows(), total=len(df)):
    if pd.isna(row['latitude']) or pd.isna(row['longitude']):
        continue
        
    try:
        url = f"https://geocoding.geo.census.gov/geocoder/geographies/coordinates?x={row['longitude']}&y={row['latitude']}&benchmark=Public_AR_Current&vintage=Current_Current&format=json"
        
        response = requests.get(url)
        
        if response.status_code == 200:
            result = response.json()
            
            if 'result' in result and 'geographies' in result['result']:
                geographies = result['result']['geographies']
                
                if '2020 Census Blocks' in geographies and len(geographies['2020 Census Blocks']) > 0:
                    block = geographies['2020 Census Blocks'][0]
                    
                    df.at[idx, 'GEOID'] = block.get('GEOID', None)
                    df.at[idx, 'STATE'] = block.get('STATE', None)
                    df.at[idx, 'COUNTY'] = block.get('COUNTY', None)
                    df.at[idx, 'TRACT'] = block.get('TRACT', None)
                    df.at[idx, 'BLOCK'] = block.get('BLOCK', None)
        
        time.sleep(0.5)
        
    except Exception as e:
        print(f"Error processing row {idx}: {e}")


df.to_csv("mental_health_facilities_nyc_with_census.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests_toolbelt/_compat.py:48
#      47 try:
# ---> 48     from requests.packages.urllib3.contrib import appengine as gaecontrib
#      49 except ImportError:
#
# ImportError: cannot import name 'appengine' from 'requests.packages.urllib3.contrib' (/Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages/urllib3/contrib/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 import pandas as pd
# ----> 2 import censusgeocode as cg
#       3 from concurrent.futures import ThreadPoolExecutor
#       4 from tqdm.notebook import tqdm
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/censusgeocode/__init__.py:10
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # This file is part of censusgeocode.
#    (...)
#       7 # http://opensource.org/licenses/LGPL-3.0
#       8 # Copyright (c) 2015-9, Neil Freeman <contact@fakeisthenewreal.org>
# ---> 10 from .censusgeocode import CensusGeocode
#      12 __version__ = '0.5.2'
#      14 cg = CensusGeocode()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/censusgeocode/censusgeocode.py:26
#      24 import requests
#      25 from requests.exceptions import RequestException
# ---> 26 from requests_toolbelt.multipart.encoder import MultipartEncoder
#      29 DEFAULT_BENCHMARK = "Public_AR_Current"
#      30 DEFAULT_VINTAGE = "Current_Current"
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests_toolbelt/__init__.py:12
#       1 # -*- coding: utf-8 -*-
#       2 """
#       3 requests-toolbelt
#       4 =================
#    (...)
#       9 :license: Apache v2.0, see LICENSE for more details
#      10 """
# ---> 12 from .adapters import SSLAdapter, SourceAddressAdapter
#      13 from .auth.guess import GuessAuth
#      14 from .multipart import (
#      15     MultipartEncoder, MultipartEncoderMonitor, MultipartDecoder,
#      16     ImproperBodyPartContentException, NonMultipartContentTypeException
#      17     )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests_toolbelt/adapters/__init__.py:12
#       1 # -*- coding: utf-8 -*-
#       2 """
#       3 requests-toolbelt.adapters
#       4 ==========================
#    (...)
#       9 :license: Apache v2.0, see LICENSE for more details
#      10 """
# ---> 12 from .ssl import SSLAdapter
#      13 from .source import SourceAddressAdapter
#      15 __all__ = ['SSLAdapter', 'SourceAddressAdapter']
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests_toolbelt/adapters/ssl.py:16
#      12 import requests
#      14 from requests.adapters import HTTPAdapter
# ---> 16 from .._compat import poolmanager
#      19 class SSLAdapter(HTTPAdapter):
#      20     """
#      21     A HTTPS Adapter for Python Requests that allows the choice of the SSL/TLS
#      22     version negotiated by Requests. This can be used either to enforce the
#    (...)
#      43     properly when used with proxies.
#      44     """
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests_toolbelt/_compat.py:50
#      48         from requests.packages.urllib3.contrib import appengine as gaecontrib
#      49     except ImportError:
# ---> 50         from urllib3.contrib import appengine as gaecontrib
#      52 PY3 = sys.version_info > (3, 0)
#      54 if PY3:
#
# ImportError: cannot import name 'appengine' from 'urllib3.contrib' (/Users/somaiyah/.pyenv/versions/3.12.7/lib/python3.12/site-packages/urllib3/contrib/__init__.py)

# %% [markdown]
# ## 👉 Output Data
#
# Output your dataframe containing your data and the Census connector codes (like tract, block, etc...).

# %%
import pandas as pd

df = pd.read_csv("mental_health_facilities_nyc_with_census.csv")  
df.head()
# Out:
#                                    name1                        name2  \
# 0                Medstar Harbor Hospital            Behavioral Health
# 1  Astor Servs for Children and Families  Astor Day Treatment Program
# 2  Astor Servs for Children and Families            Highbridge Clinic
# 3  Astor Servs for Children and Families     Lawrence F Hickey Center
# 4  Astor Servs for Children and Families                Tilden Clinic
#
#                      street1    street2      city state    zip         phone  \
# 0  3001 South Hanover Street  Suite 164  Brooklyn    MD  21225  410-350-7550
# 1    516 East Tremont Avenue        NaN     Bronx    NY  10457  347-978-2450
# 2    1419 Shakespeare Avenue  1st Floor     Bronx    NY  10452  718-231-3400
# 3           4010 Dyre Avenue        NaN     Bronx    NY  10466  845-515-3000
# 4          750 Tilden Street        NaN     Bronx    NY  10467  718-231-3400
#
#               intake1 intake2  ...  \
# 0                 NaN     NaN  ...
# 1  929-285-3917 x1096     NaN  ...
# 2     718-732-7080 x0     NaN  ...
# 3        718-515-3000     NaN  ...
# 4                 NaN     NaN  ...
#
#                                    service_code_info  \
# 0  MH * OP PHDT * PSY * ARIPI CLOZA OLANZ OLANZF ...
# 1  MH SUMH * PHDT * PH * CHLOR HALOP PERPH ANTPYC...
# 2  SA MH SUMH * OP * OMH * NSC ANTPYCH * CBT CFT ...
# 3  MH * PHDT * PH * ANTPYCH * CBT CFT GT IPT TELE...
# 4  SA MH SUMH * OP * OMH * ANTPYCH * CBT CFT DBT ...
#
#                                     full_address  \
# 0  3001 South Hanover Street, Brooklyn, NY 21225
# 1       516 East Tremont Avenue, Bronx, NY 10457
# 2       1419 Shakespeare Avenue, Bronx, NY 10452
# 3              4010 Dyre Avenue, Bronx, NY 10466
# 4             750 Tilden Street, Bronx, NY 10467
#
#                                             location   latitude  longitude  \
# 0                                                NaN        NaN        NaN
# 1  516, East Tremont Avenue, East Tremont, The Br...  40.846700 -73.896822
# 2  1419, Shakespeare Avenue, High Bridge, The Bro...  40.842533 -73.921238
# 3  Public School 15, 4010, Dyre Avenue, Parkside,...  40.890946 -73.830730
# 4  750, Tilden Street, Williams Bridge, The Bronx...  40.876680 -73.862771
#
#           GEOID  STATE  COUNTY    TRACT   BLOCK
# 0           NaN    NaN     NaN      NaN     NaN
# 1  3.600504e+14   36.0     5.0  39500.0  4001.0
# 2  3.600502e+14   36.0     5.0  21302.0  3000.0
# 3  3.600505e+14   36.0     5.0  45600.0  2002.0
# 4  3.600504e+14   36.0     5.0  38000.0  4006.0
#
# [5 rows x 22 columns]
